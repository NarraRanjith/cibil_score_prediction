# %%
d={1:1,2:2,3:3}

# %%
d[1]

# %%
d.1

# %%
from box import ConfigBox
d2=ConfigBox(d)

# %%
d2.1

# %%
def prod(x:int,y:int) -> int:
    return x*y

# %%
prod(2,4)

# %%
prod(2,"4")

# %%
from ensure import ensure_annotations
#to throw error if user uses different datatype
@ensure_annotations
def prod(x:int,y:int) -> int:
    return x*y
